# %% [markdown]
# <a href="https://colab.research.google.com/github/shirataki-takipon/image_classification_traning/blob/master/learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/image_classification_traning')
import ic_module as ic
import os.path as op

# %%
# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (264, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 21/22 [===========================>..] - ETA: 0s - loss: 1.1373 - accuracy: 0.3810
# Epoch 00001: val_loss improved from inf to 1.11000, saving model to best.hdf5
# 22/22 [==============================] - 2s 75ms/step - loss: 1.1345 - accuracy: 0.3736 - val_loss: 1.1100 - val_accuracy: 0.3333
# Epoch 2/50
# 21/22 [===========================>..] - ETA: 0s - loss: 1.0819 - accuracy: 0.4464
# Epoch 00002: val_loss improved from 1.11000 to 1.10361, saving model to best.hdf5
# 22/22 [==============================] - 1s 62ms/step - loss: 1.0802 - accuracy: 0.4483 - val_loss: 1.1036 - val_accuracy: 0.3333
# Epoch 3/50
# 21/22 [===========================>..] - ETA: 0s - loss: 1.0596 - accuracy: 0.4643
# Epoch 00003: val_loss did not improve from 1.10361
# 22/22 [==============================] - 1s 60ms/step - loss: 1.0590 - accuracy: 0.4655 - val_loss: 1.1214 - val_accuracy: 0.3333
# Epoch 4/50
# ...
